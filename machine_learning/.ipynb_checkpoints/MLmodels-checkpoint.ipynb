# %%
# generic data science libraries
import pandas as pd
import numpy as np

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# import scikit-learn
from sklearn.model_selection import train_test_split

# models
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

from sklearn.linear_model import LogisticRegression


import pickle

# metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.metrics import accuracy_score, classification_report, auc, confusion_matrix, roc_curve

# %%
# df = pd.read_csv("..\data\DallasAccidents.csv")
df = pd.read_csv("..\..\TexasAccidents.csv")
pd.set_option('display.max_columns', None)
df.head()
# Out:
#          ID    Source    TMC  Severity           Start_Time  \
# 0  A-261009  MapQuest  201.0         2  2016-11-30 16:03:54
# 1  A-261010  MapQuest  201.0         2  2016-11-30 16:32:18
# 2  A-261011  MapQuest  201.0         2  2016-11-30 16:31:45
# 3  A-261012  MapQuest  201.0         2  2016-11-30 16:06:49
# 4  A-261013  MapQuest  201.0         3  2016-11-30 16:35:01
#
#               End_Time  Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  \
# 0  2016-11-30 17:20:00  30.336502 -97.755646      NaN      NaN          0.01
# 1  2016-11-30 17:47:02  30.328165 -97.694305      NaN      NaN          0.00
# 2  2016-11-30 17:46:34  30.326077 -97.692307      NaN      NaN          0.00
# 3  2016-11-30 17:27:00  32.856014 -97.513084      NaN      NaN          0.01
# 4  2016-11-30 17:49:39  32.797668 -97.212090      NaN      NaN          0.01
#
#                                          Description  Number  \
# 0  Accident on RM-2222 Northland Dr at Mo Pac Exp...     NaN
# 1  Accident on Grand Canyon Dr between Westheimer...  1128.0
# 2         Accident on Saint Johns Ave at Cameron Rd.  7197.0
# 3  #2 lane blocked and right hand shoulder blocke...     NaN
# 4  #2 lane blocked and right hand shoulder blocke...     NaN
#
#               Street Side        City   County State     Zipcode Country  \
# 0       Mopac Expy S    R      Austin   Travis    TX       78731      US
# 1  E Saint Johns Ave    L      Austin   Travis    TX  78752-2826      US
# 2         Cameron Rd    R      Austin   Travis    TX       78752      US
# 3   Hanger Cutoff Rd    R  Fort Worth  Tarrant    TX       76135      US
# 4            I-820 N    R  Fort Worth  Tarrant    TX       76118      US
#
#      Timezone Airport_Code    Weather_Timestamp  Temperature(F)  \
# 0  US/Central         KATT  2016-11-30 15:51:00            66.0
# 1  US/Central         KATT  2016-11-30 16:51:00            62.1
# 2  US/Central         KATT  2016-11-30 16:51:00            62.1
# 3  US/Central         KAWN  2016-11-30 16:00:00             NaN
# 4  US/Central         KFWD                  NaN             NaN
#
#    Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi) Wind_Direction  \
# 0            NaN         24.0         30.01            10.0            NNW
# 1            NaN         25.0         30.03            10.0          North
# 2            NaN         25.0         30.03            10.0          North
# 3            NaN          NaN           NaN             NaN          North
# 4            NaN          NaN           NaN             NaN            NaN
#
#    Wind_Speed(mph)  Precipitation(in) Weather_Condition  Amenity   Bump  \
# 0              5.8                NaN             Clear    False  False
# 1              4.6                NaN             Clear    False  False
# 2              4.6                NaN             Clear    False  False
# 3              NaN                NaN               NaN    False  False
# 4              NaN                NaN               NaN    False  False
#
#    Crossing  Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# 0     False     False     False    False    False       False    False  False
# 1     False     False     False    False    False       False    False  False
# 2     False     False     False    False    False       False     True  False
# 3     False     False     False    False    False       False    False  False
# 4     False     False     False    False    False       False    False  False
#
#    Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 0            False           False         False            Day
# 1            False           False         False            Day
# 2            False            True         False            Day
# 3            False           False         False            Day
# 4            False           False         False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Day               Day                   Day
# 1            Day               Day                   Day
# 2            Day               Day                   Day
# 3            Day               Day                   Day
# 4            Day               Day                   Day

# %% [markdown]
# # Get Info on CSV

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376445 entries, 0 to 376444
# Data columns (total 49 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID                     376445 non-null  object
#  1   Source                 376445 non-null  object
#  2   TMC                    301303 non-null  float64
#  3   Severity               376445 non-null  int64
#  4   Start_Time             376445 non-null  object
#  5   End_Time               376445 non-null  object
#  6   Start_Lat              376445 non-null  float64
#  7   Start_Lng              376445 non-null  float64
#  8   End_Lat                75142 non-null   float64
#  9   End_Lng                75142 non-null   float64
#  10  Distance(mi)           376445 non-null  float64
#  11  Description            376444 non-null  object
#  12  Number                 154562 non-null  float64
#  13  Street                 376445 non-null  object
#  14  Side                   376445 non-null  object
#  15  City                   376445 non-null  object
#  16  County                 376445 non-null  object
#  17  State                  376445 non-null  object
#  18  Zipcode                376445 non-null  object
#  19  Country                376445 non-null  object
#  20  Timezone               376414 non-null  object
#  21  Airport_Code           376409 non-null  object
#  22  Weather_Timestamp      371186 non-null  object
#  23  Temperature(F)         369856 non-null  float64
#  24  Wind_Chill(F)          154502 non-null  float64
#  25  Humidity(%)            369336 non-null  float64
#  26  Pressure(in)           370167 non-null  float64
#  27  Visibility(mi)         369001 non-null  float64
#  28  Wind_Direction         370234 non-null  object
#  29  Wind_Speed(mph)        338791 non-null  float64
#  30  Precipitation(in)      152075 non-null  float64
#  31  Weather_Condition      368894 non-null  object
#  32  Amenity                376445 non-null  bool
#  33  Bump                   376445 non-null  bool
#  34  Crossing               376445 non-null  bool
#  35  Give_Way               376445 non-null  bool
#  36  Junction               376445 non-null  bool
#  37  No_Exit                376445 non-null  bool
#  38  Railway                376445 non-null  bool
#  39  Roundabout             376445 non-null  bool
#  40  Station                376445 non-null  bool
#  41  Stop                   376445 non-null  bool
#  42  Traffic_Calming        376445 non-null  bool
#  43  Traffic_Signal         376445 non-null  bool
#  44  Turning_Loop           376445 non-null  bool
#  45  Sunrise_Sunset         376445 non-null  object
#  46  Civil_Twilight         376445 non-null  object
#  47  Nautical_Twilight      376445 non-null  object
#  48  Astronomical_Twilight  376445 non-null  object
# dtypes: bool(13), float64(14), int64(1), object(21)
# memory usage: 108.1+ MB

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'TMC', 'Severity', 'Start_Time', 'End_Time',
#        'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)',
#        'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
#        'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
#        'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.nunique()
# Out:
# ID                       376445
# Source                        3
# TMC                          20
# Severity                      4
# Start_Time               356659
# End_Time                 361235
# Start_Lat                126424
# Start_Lng                111533
# End_Lat                   32169
# End_Lng                   32330
# Distance(mi)               3924
# Description              203353
# Number                    14342
# Street                    22489
# Side                          2
# City                        755
# County                      219
# State                         1
# Zipcode                   42054
# Country                       1
# Timezone                      2
# Airport_Code                185
# Weather_Timestamp        132229
# Temperature(F)              550
# Wind_Chill(F)               449
# Humidity(%)                  97
# Pressure(in)                488
# Visibility(mi)               48
# Wind_Direction               24
# Wind_Speed(mph)              85
# Precipitation(in)           159
# Weather_Condition            70
# Amenity                       2
# Bump                          2
# Crossing                      2
# Give_Way                      2
# Junction                      2
# No_Exit                       2
# Railway                       2
# Roundabout                    2
# Station                       2
# Stop                          2
# Traffic_Calming               2
# Traffic_Signal                2
# Turning_Loop                  1
# Sunrise_Sunset                2
# Civil_Twilight                2
# Nautical_Twilight             2
# Astronomical_Twilight         2
# dtype: int64

# %%
df["Stop"].value_counts()
# Out:
# False    368012
# True       8433
# Name: Stop, dtype: int64

# %%
df["Street"].value_counts()
# Out:
# I-45 N            6707
# I-45 S            4661
# I-35 N            4488
# I-35 S            4449
# I-10 W            4022
#                   ...
# Sturges Dr           1
#  Richvale Ln         1
# Slide Rd             1
#  W 29th St           1
#  Quail Glen Dr       1
# Name: Street, Length: 22489, dtype: int64

# %% [markdown]
# # Clean Data

# %%
# Sort Street Type
df.loc[df['Street'].str.contains(' Ln'), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains(' Lane'), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains(' Way'), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains(' Sq'), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains(' Pl'), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains(' Plz'), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains(' Rd'), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains(' Road'), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains(' Dr'), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains(' Ave'), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains(' Trl'), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains(' Trail'), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains(' Blvd'), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains(' Boulevard'), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains(' St'), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains(' Cir'), 'Road_Type'] = 'Street'

df.loc[df['Street'].str.contains('FM '), 'Road_Type'] = 'Street'
df.loc[df['Street'].str.contains('Cr '), 'Road_Type'] = 'Street'

df.loc[df['Street'].str.contains(' Hwy'), 'Road_Type'] = 'Highway'
df.loc[df['Street'].str.contains('Highway'), 'Road_Type'] = 'Highway'
df.loc[df['Street'].str.contains('US-'), 'Road_Type'] = 'Highway'
df.loc[df['Street'].str.contains('Loop '), 'Road_Type'] = 'Highway'
df.loc[df['Street'].str.contains(' Fwy'), 'Road_Type'] = 'Highway'
df.loc[df['Street'].str.contains(' Freeway'), 'Road_Type'] = 'Highway'
df.loc[df['Street'].str.contains(' Tollway'), 'Road_Type'] = 'Highway'
df.loc[df['Street'].str.contains('TX-'), 'Road_Type'] = 'Highway'
df.loc[df['Street'].str.contains('I-'), 'Road_Type'] = 'Highway'
df.loc[df['Street'].str.contains(' Ext'), 'Road_Type'] = 'Highway'
df.loc[df['Street'].str.contains(' Expy'), 'Road_Type'] = 'Highway'
df.loc[df['Street'].str.contains(' Tpk'), 'Road_Type'] = 'Highway'
df.loc[df['Street'].str.contains(' Connection'), 'Road_Type'] = 'Highway'


#df.loc[df['Street'].str.contains(''), 'Road_Type'] = 'NA'

# %%
df["Road_Type"].count()
# Out:
# 356466

# %%
df["Road_Type"].value_counts()
# Out:
# Street     208661
# Highway    147805
# Name: Road_Type, dtype: int64

# %%
# Clear
df.loc[df['Weather_Condition'].str.contains('Fair', na=False), 'Weather_Condition1'] = 'Clear'
df.loc[df['Weather_Condition'].str.contains('Clear', na=False), 'Weather_Condition1'] = 'Clear'
df.loc[df['Weather_Condition'].str.contains('N/A Precipitation', na=False), 'Weather_Condition1'] = 'Clear'

# Cloudy
df.loc[df['Weather_Condition'].str.contains('Cloudy', na=False), 'Weather_Condition1'] = 'Cloudy'
df.loc[df['Weather_Condition'].str.contains('Clouds', na=False), 'Weather_Condition1'] = 'Cloudy'
df.loc[df['Weather_Condition'].str.contains('Overcast', na=False), 'Weather_Condition1'] = 'Cloudy'

#Fog/Haze
df.loc[df['Weather_Condition'].str.contains('Fog', na=False), 'Weather_Condition1'] = 'Fog_Haze'
df.loc[df['Weather_Condition'].str.contains('Smoke', na=False), 'Weather_Condition1'] = 'Fog_Haze'
df.loc[df['Weather_Condition'].str.contains('Dust', na=False), 'Weather_Condition1'] = 'Fog_Haze'
df.loc[df['Weather_Condition'].str.contains('Haze', na=False), 'Weather_Condition1'] = 'Fog_Haze'
df.loc[df['Weather_Condition'].str.contains('Sand', na=False), 'Weather_Condition1'] = 'Fog_Haze'

#Rain
df.loc[df['Weather_Condition'].str.contains('Rain', na=False), 'Weather_Condition1'] = 'Rain'
df.loc[df['Weather_Condition'].str.contains('Mist', na=False), 'Weather_Condition1'] = 'Rain'
df.loc[df['Weather_Condition'].str.contains('Drizzle', na=False), 'Weather_Condition1'] = 'Rain'
df.loc[df['Weather_Condition'].str.contains('Shower', na=False), 'Weather_Condition1'] = 'Rain'

# Thunder Storm
df.loc[df['Weather_Condition'].str.contains('Thunder', na=False), 'Weather_Condition1'] = 'Thunder_Storm'
df.loc[df['Weather_Condition'].str.contains('T-Storm', na=False), 'Weather_Condition1'] = 'Thunder_Storm'

# Wintery Mix
df.loc[df['Weather_Condition'].str.contains('Wintry', na=False), 'Weather_Condition1'] = 'Wintery_Mix'
df.loc[df['Weather_Condition'].str.contains('Icy', na=False), 'Weather_Condition1'] = 'Wintery_Mix'
df.loc[df['Weather_Condition'].str.contains('Ice', na=False), 'Weather_Condition1'] = 'Wintery_Mix'
df.loc[df['Weather_Condition'].str.contains('Snow', na=False), 'Weather_Condition1'] = 'Wintery_Mix'

# %%
df["Weather_Condition1"].unique()
# Out:
# array(['Clear', nan, 'Cloudy', 'Rain', 'Fog_Haze', 'Wintery_Mix',
#        'Thunder_Storm'], dtype=object)

# %%
df["Weather_Condition1"].value_counts()
# Out:
# Cloudy           199473
# Clear            135778
# Rain              21944
# Fog_Haze           6885
# Thunder_Storm      4575
# Wintery_Mix         239
# Name: Weather_Condition1, dtype: int64

# %%
# Add Initial Severity Column
df.loc[df['Severity'] == 1, 'Init_Severity'] = 0
df.loc[df['Severity'] == 2, 'Init_Severity'] = 0
df.loc[df['Severity'] == 3, 'Init_Severity'] = 1
df.loc[df['Severity'] == 4, 'Init_Severity'] = 1

# %%
df["Init_Severity"].value_counts()
# Out:
# 0.0    274852
# 1.0    101593
# Name: Init_Severity, dtype: int64

# %% [markdown]
# # Get Columns for new Data Frame

# %%
df_sub = df.loc[:, [ 'Severity', 'Init_Severity', 'Distance(mi)', 'Side', 'Temperature(F)', 'Humidity(%)', 'Pressure(in)',
       'Visibility(mi)', 'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition1', 'Amenity', 'Bump', 'Crossing',
       'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
       'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Sunrise_Sunset', 'Civil_Twilight',
       'Nautical_Twilight', 'Astronomical_Twilight', 'Road_Type']]

# %%
df_sub = df_sub.dropna(subset=['Weather_Condition1', 'Wind_Speed(mph)', 'Humidity(%)', 
                               'Temperature(F)', 'Pressure(in)', 'Visibility(mi)', 'Road_Type'])

# %%
df_sub["Weather_Condition1"].unique()
# Out:
# array(['Clear', 'Cloudy', 'Rain', 'Fog_Haze', 'Wintery_Mix',
#        'Thunder_Storm'], dtype=object)

# %%
df_sub["Precipitation(in)"].unique()
# Out:
# array([ nan, 0.  , 0.06, 0.05, 0.01, 0.1 , 0.02, 0.04, 0.03, 0.12, 0.16,
#        0.22, 0.2 , 0.13, 0.07, 0.09, 0.15, 0.08, 0.11, 0.27, 0.14, 0.18,
#        0.3 , 0.19, 0.39, 0.17, 0.86, 0.42, 0.32, 0.38, 0.43, 0.21, 0.93,
#        0.24, 0.78, 0.25, 1.37, 0.5 , 0.72, 0.26, 1.13, 0.41, 0.31, 0.58,
#        0.48, 0.28, 0.29, 2.28, 0.34, 0.68, 0.73, 0.23, 0.62, 0.71, 0.47,
#        0.4 , 0.82, 0.33, 0.54, 0.66, 1.  , 0.6 , 0.83, 0.57, 0.52, 0.49,
#        0.79, 0.37, 0.61, 0.99, 0.53, 0.56, 1.28, 0.46, 1.11, 1.46, 1.06,
#        0.65, 0.55, 0.77, 0.69, 0.36, 0.98, 1.12, 0.85, 0.89, 0.63, 1.58,
#        1.6 , 0.81, 1.39, 1.38, 1.49, 0.84, 0.35, 1.25, 0.59, 0.64, 1.48,
#        1.53, 1.16, 0.67, 0.76, 1.65, 0.44, 1.26, 1.19, 1.08, 0.45, 0.96,
#        0.7 , 0.8 , 0.9 , 1.62, 0.97, 0.91, 2.07, 1.32, 1.81, 0.74, 1.75,
#        0.92, 0.51, 1.42, 0.95, 2.53, 1.35, 1.41, 0.87, 1.15, 0.75, 1.69,
#        1.3 , 1.33, 2.26, 0.94, 1.01, 1.14, 1.03, 1.09, 1.21, 2.55, 1.87,
#        1.4 , 0.88, 1.72, 1.05, 1.04, 1.31, 2.31, 2.04, 2.1 ])

# %%
df_sub["Precipitation(in)"].fillna(0, inplace=True)

# %%
df_sub["Precipitation(in)"].unique()
# Out:
# array([0.  , 0.06, 0.05, 0.01, 0.1 , 0.02, 0.04, 0.03, 0.12, 0.16, 0.22,
#        0.2 , 0.13, 0.07, 0.09, 0.15, 0.08, 0.11, 0.27, 0.14, 0.18, 0.3 ,
#        0.19, 0.39, 0.17, 0.86, 0.42, 0.32, 0.38, 0.43, 0.21, 0.93, 0.24,
#        0.78, 0.25, 1.37, 0.5 , 0.72, 0.26, 1.13, 0.41, 0.31, 0.58, 0.48,
#        0.28, 0.29, 2.28, 0.34, 0.68, 0.73, 0.23, 0.62, 0.71, 0.47, 0.4 ,
#        0.82, 0.33, 0.54, 0.66, 1.  , 0.6 , 0.83, 0.57, 0.52, 0.49, 0.79,
#        0.37, 0.61, 0.99, 0.53, 0.56, 1.28, 0.46, 1.11, 1.46, 1.06, 0.65,
#        0.55, 0.77, 0.69, 0.36, 0.98, 1.12, 0.85, 0.89, 0.63, 1.58, 1.6 ,
#        0.81, 1.39, 1.38, 1.49, 0.84, 0.35, 1.25, 0.59, 0.64, 1.48, 1.53,
#        1.16, 0.67, 0.76, 1.65, 0.44, 1.26, 1.19, 1.08, 0.45, 0.96, 0.7 ,
#        0.8 , 0.9 , 1.62, 0.97, 0.91, 2.07, 1.32, 1.81, 0.74, 1.75, 0.92,
#        0.51, 1.42, 0.95, 2.53, 1.35, 1.41, 0.87, 1.15, 0.75, 1.69, 1.3 ,
#        1.33, 2.26, 0.94, 1.01, 1.14, 1.03, 1.09, 1.21, 2.55, 1.87, 1.4 ,
#        0.88, 1.72, 1.05, 1.04, 1.31, 2.31, 2.04, 2.1 ])

# %%
# Rename Columns

df_sub.rename(columns={"Distance(mi)": "Distance", "Temperature(F)": "Temperature",
                  "Humidity(%)": "Humidity", "Pressure(in)": "Pressure", "Visibility(mi)": "Visibility",
                  "Wind_Speed(mph)": "Wind_Speed", "Precipitation(in)": "Precipitation",})
# Out:
#         Severity  Init_Severity  Distance Side  Temperature  Humidity  \
# 0              2            0.0     0.010    R         66.0      24.0
# 1              2            0.0     0.000    L         62.1      25.0
# 2              2            0.0     0.000    R         62.1      25.0
# 5              2            0.0     0.010    R         60.1      24.0
# 6              3            1.0     0.010    R         61.0      22.0
# ...          ...            ...       ...  ...          ...       ...
# 376440         2            0.0     0.493    R         76.0      91.0
# 376441         3            1.0     0.399    R         76.0      91.0
# 376442         3            1.0     0.520    R         76.0      91.0
# 376443         3            1.0     1.153    R         84.0      72.0
# 376444         3            1.0     1.228    R         83.0      74.0
#
#         Pressure  Visibility  Wind_Speed  Precipitation Weather_Condition1  \
# 0          30.01        10.0         5.8           0.00              Clear
# 1          30.03        10.0         4.6           0.00              Clear
# 2          30.03        10.0         4.6           0.00              Clear
# 5          30.00        10.0         5.8           0.00              Clear
# 6          30.01        10.0         4.6           0.00              Clear
# ...          ...         ...         ...            ...                ...
# 376440     29.88         1.0        12.0           0.68      Thunder_Storm
# 376441     29.88         0.5        15.0           0.25      Thunder_Storm
# 376442     29.88         0.5        15.0           0.25      Thunder_Storm
# 376443     29.77        10.0        13.0           0.00             Cloudy
# 376444     29.72        10.0        12.0           0.00              Clear
#
#         Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  Railway  \
# 0         False  False     False     False     False    False    False
# 1         False  False     False     False     False    False    False
# 2         False  False     False     False     False    False    False
# 5         False  False     False     False     False    False    False
# 6         False  False     False     False     False    False    False
# ...         ...    ...       ...       ...       ...      ...      ...
# 376440    False  False     False     False     False    False    False
# 376441    False  False     False     False     False    False    False
# 376442    False  False     False     False     False    False    False
# 376443    False  False     False     False     False    False    False
# 376444    False  False     False     False      True    False    False
#
#         Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# 0            False    False  False            False           False
# 1            False    False  False            False           False
# 2            False     True  False            False            True
# 5            False    False  False            False           False
# 6            False    False  False            False           False
# ...            ...      ...    ...              ...             ...
# 376440       False    False  False            False           False
# 376441       False    False  False            False           False
# 376442       False    False  False            False           False
# 376443       False    False  False            False           False
# 376444       False    False  False            False           False
#
#         Turning_Loop Sunrise_Sunset Civil_Twilight Nautical_Twilight  \
# 0              False            Day            Day               Day
# 1              False            Day            Day               Day
# 2              False            Day            Day               Day
# 5              False            Day            Day               Day
# 6              False            Day            Day               Day
# ...              ...            ...            ...               ...
# 376440         False            Day            Day               Day
# 376441         False            Day            Day               Day
# 376442         False            Day            Day               Day
# 376443         False            Day            Day               Day
# 376444         False            Day            Day               Day
#
#        Astronomical_Twilight Road_Type
# 0                        Day   Highway
# 1                        Day    Street
# 2                        Day    Street
# 5                        Day    Street
# 6                        Day   Highway
# ...                      ...       ...
# 376440                   Day   Highway
# 376441                   Day   Highway
# 376442                   Day   Highway
# 376443                   Day   Highway
# 376444                   Day   Highway
#
# [317975 rows x 29 columns]

# %%
df_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317975 entries, 0 to 376444
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Severity               317975 non-null  int64
#  1   Init_Severity          317975 non-null  float64
#  2   Distance(mi)           317975 non-null  float64
#  3   Side                   317975 non-null  object
#  4   Temperature(F)         317975 non-null  float64
#  5   Humidity(%)            317975 non-null  float64
#  6   Pressure(in)           317975 non-null  float64
#  7   Visibility(mi)         317975 non-null  float64
#  8   Wind_Speed(mph)        317975 non-null  float64
#  9   Precipitation(in)      317975 non-null  float64
#  10  Weather_Condition1     317975 non-null  object
#  11  Amenity                317975 non-null  bool
#  12  Bump                   317975 non-null  bool
#  13  Crossing               317975 non-null  bool
#  14  Give_Way               317975 non-null  bool
#  15  Junction               317975 non-null  bool
#  16  No_Exit                317975 non-null  bool
#  17  Railway                317975 non-null  bool
#  18  Roundabout             317975 non-null  bool
#  19  Station                317975 non-null  bool
#  20  Stop                   317975 non-null  bool
#  21  Traffic_Calming        317975 non-null  bool
#  22  Traffic_Signal         317975 non-null  bool
#  23  Turning_Loop           317975 non-null  bool
#  24  Sunrise_Sunset         317975 non-null  object
#  25  Civil_Twilight         317975 non-null  object
#  26  Nautical_Twilight      317975 non-null  object
#  27  Astronomical_Twilight  317975 non-null  object
#  28  Road_Type              317975 non-null  object
# dtypes: bool(13), float64(8), int64(1), object(7)
# memory usage: 45.2+ MB

# %% [markdown]
# # Dummie Columns

# %%
obj_cols_to_dum = ['Side',
    'Weather_Condition1',
    'Sunrise_Sunset', 
    'Civil_Twilight', 
    'Nautical_Twilight',
    'Astronomical_Twilight',
    'Road_Type']

#     'Amenity',
#     'Bump', 
#     'Crossing',
#     'Give_Way',
#     'Junction', 
#     'No_Exit', 
#     'Railway', 
#     'Roundabout', 
#     'Station',
#     'Stop', 
#     'Traffic_Calming', 
#     'Traffic_Signal', 
#     'Turning_Loop',

# get dums
dums_linear = pd.get_dummies(df_sub.loc[:, obj_cols_to_dum], drop_first=True)
dums_other = pd.get_dummies(df_sub.loc[:, obj_cols_to_dum], drop_first=False)

#concat
df_sub_linear = pd.concat([df_sub, dums_linear], axis=1)
df_sub_other = pd.concat([df_sub, dums_other], axis=1)

#drop original
df_sub_linear = df_sub_linear.drop(obj_cols_to_dum, axis=1)
df_sub_other = df_sub_other.drop(obj_cols_to_dum, axis=1)

# %% [markdown]
# # Get Severity and Mild Data Frames

# %%
df_mild_linear = df_sub_linear.loc[~(df['Severity'] == 3) & ~(df['Severity'] == 4)]
df_mild_other = df_sub_other.loc[~(df['Severity'] == 3) & ~(df['Severity'] == 4)]
df_severe_linear = df_sub_linear.loc[~(df['Severity'] == 1) & ~(df['Severity'] == 2)]
df_severe_other = df_sub_other.loc[~(df['Severity'] == 1) & ~(df['Severity'] == 2)]

df_mild_linear = df_mild_linear.drop(["Init_Severity"], axis=1)
df_mild_other = df_mild_other.drop(["Init_Severity"], axis=1)
df_severe_linear = df_severe_linear.drop(["Init_Severity"], axis=1)
df_severe_other = df_severe_other.drop(["Init_Severity"], axis=1)

# %%
df_sub_other = df_sub_other.drop(["Severity"], axis=1)
df_sub_linear = df_sub_linear.drop(["Severity"], axis=1)

# %%
df_sub_other.head()
# Out:
#    Init_Severity  Distance(mi)  Temperature(F)  Humidity(%)  Pressure(in)  \
# 0            0.0          0.01            66.0         24.0         30.01
# 1            0.0          0.00            62.1         25.0         30.03
# 2            0.0          0.00            62.1         25.0         30.03
# 5            0.0          0.01            60.1         24.0         30.00
# 6            1.0          0.01            61.0         22.0         30.01
#
#    Visibility(mi)  Wind_Speed(mph)  Precipitation(in)  Amenity   Bump  \
# 0            10.0              5.8                0.0    False  False
# 1            10.0              4.6                0.0    False  False
# 2            10.0              4.6                0.0    False  False
# 5            10.0              5.8                0.0    False  False
# 6            10.0              4.6                0.0    False  False
#
#    Crossing  Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# 0     False     False     False    False    False       False    False  False
# 1     False     False     False    False    False       False    False  False
# 2     False     False     False    False    False       False     True  False
# 5     False     False     False    False    False       False    False  False
# 6     False     False     False    False    False       False    False  False
#
#    Traffic_Calming  Traffic_Signal  Turning_Loop  Side_L  Side_R  \
# 0            False           False         False       0       1
# 1            False           False         False       1       0
# 2            False            True         False       0       1
# 5            False           False         False       0       1
# 6            False           False         False       0       1
#
#    Weather_Condition1_Clear  Weather_Condition1_Cloudy  \
# 0                         1                          0
# 1                         1                          0
# 2                         1                          0
# 5                         1                          0
# 6                         1                          0
#
#    Weather_Condition1_Fog_Haze  Weather_Condition1_Rain  \
# 0                            0                        0
# 1                            0                        0
# 2                            0                        0
# 5                            0                        0
# 6                            0                        0
#
#    Weather_Condition1_Thunder_Storm  Weather_Condition1_Wintery_Mix  \
# 0                                 0                               0
# 1                                 0                               0
# 2                                 0                               0
# 5                                 0                               0
# 6                                 0                               0
#
#    Sunrise_Sunset_Day  Sunrise_Sunset_Night  Civil_Twilight_Day  \
# 0                   1                     0                   1
# 1                   1                     0                   1
# 2                   1                     0                   1
# 5                   1                     0                   1
# 6                   1                     0                   1
#
#    Civil_Twilight_Night  Nautical_Twilight_Day  Nautical_Twilight_Night  \
# 0                     0                      1                        0
# 1                     0                      1                        0
# 2                     0                      1                        0
# 5                     0                      1                        0
# 6                     0                      1                        0
#
#    Astronomical_Twilight_Day  Astronomical_Twilight_Night  Road_Type_Highway  \
# 0                          1                            0                  1
# 1                          1                            0                  0
# 2                          1                            0                  0
# 5                          1                            0                  0
# 6                          1                            0                  1
#
#    Road_Type_Street
# 0                 0
# 1                 1
# 2                 1
# 5                 1
# 6                 0

# %% [markdown]
# # Correlations

# %%
df_sub_other.corr()
# Out:
#                                   Init_Severity  Distance(mi)  Temperature(F)  \
# Init_Severity                          1.000000      0.063437        0.010268
# Distance(mi)                           0.063437      1.000000       -0.039435
# Temperature(F)                         0.010268     -0.039435        1.000000
# Humidity(%)                            0.015818      0.006973       -0.299194
# Pressure(in)                           0.048974     -0.009862       -0.140921
# Visibility(mi)                        -0.005898      0.006505        0.191987
# Wind_Speed(mph)                        0.058645      0.003338        0.033429
# Precipitation(in)                      0.022178     -0.001220       -0.039488
# Amenity                               -0.075669     -0.022151        0.019778
# Bump                                  -0.006837     -0.001563        0.000085
# Crossing                              -0.133186     -0.050808        0.008360
# Give_Way                               0.019790     -0.010526        0.010909
# Junction                               0.143825      0.101699       -0.011858
# No_Exit                               -0.015705     -0.006215        0.000266
# Railway                               -0.048806     -0.015917       -0.002282
# Roundabout                            -0.004905     -0.001362       -0.003968
# Station                               -0.068260     -0.020821        0.024554
# Stop                                  -0.082532     -0.025841        0.004605
# Traffic_Calming                       -0.009955     -0.003426        0.002518
# Traffic_Signal                        -0.223582     -0.100343        0.034125
# Turning_Loop                                NaN           NaN             NaN
# Side_L                                -0.240818     -0.071691        0.024649
# Side_R                                 0.240818      0.071691       -0.024649
# Weather_Condition1_Clear              -0.010850      0.022926       -0.014781
# Weather_Condition1_Cloudy             -0.007491     -0.022516        0.106161
# Weather_Condition1_Fog_Haze           -0.014166     -0.001738       -0.049393
# Weather_Condition1_Rain                0.031327      0.001015       -0.161454
# Weather_Condition1_Thunder_Storm       0.029099     -0.002714        0.007166
# Weather_Condition1_Wintery_Mix        -0.000092      0.019200       -0.065135
# Sunrise_Sunset_Day                    -0.022088     -0.056930        0.297967
# Sunrise_Sunset_Night                   0.022088      0.056930       -0.297967
# Civil_Twilight_Day                    -0.014766     -0.062309        0.273854
# Civil_Twilight_Night                   0.014766      0.062309       -0.273854
# Nautical_Twilight_Day                 -0.003523     -0.067793        0.249733
# Nautical_Twilight_Night                0.003523      0.067793       -0.249733
# Astronomical_Twilight_Day              0.009981     -0.072134        0.231905
# Astronomical_Twilight_Night           -0.009981      0.072134       -0.231905
# Road_Type_Highway                      0.440856      0.172745       -0.045925
# Road_Type_Street                      -0.440856     -0.172745        0.045925
#
#                                   Humidity(%)  Pressure(in)  Visibility(mi)  \
# Init_Severity                        0.015818      0.048974       -0.005898
# Distance(mi)                         0.006973     -0.009862        0.006505
# Temperature(F)                      -0.299194     -0.140921        0.191987
# Humidity(%)                          1.000000      0.154491       -0.454839
# Pressure(in)                         0.154491      1.000000       -0.020456
# Visibility(mi)                      -0.454839     -0.020456        1.000000
# Wind_Speed(mph)                     -0.137554      0.007541        0.031710
# Precipitation(in)                    0.143523      0.001085       -0.257520
# Amenity                             -0.020076      0.006007        0.006491
# Bump                                 0.000108      0.001122        0.001070
# Crossing                             0.002320      0.050308       -0.002569
# Give_Way                             0.011538      0.022481       -0.006828
# Junction                             0.008025      0.010979        0.004066
# No_Exit                              0.002628      0.008209       -0.002502
# Railway                              0.008689      0.019688       -0.005064
# Roundabout                           0.003886     -0.002474       -0.006079
# Station                             -0.019405      0.005446        0.006948
# Stop                                 0.027153      0.049544       -0.019992
# Traffic_Calming                     -0.004240      0.000611        0.000202
# Traffic_Signal                      -0.025450     -0.012059        0.003554
# Turning_Loop                              NaN           NaN             NaN
# Side_L                              -0.014280     -0.008039       -0.001108
# Side_R                               0.014280      0.008039        0.001108
# Weather_Condition1_Clear            -0.345431     -0.068980        0.254410
# Weather_Condition1_Cloudy            0.136680      0.068707        0.077943
# Weather_Condition1_Fog_Haze          0.127700      0.001235       -0.369556
# Weather_Condition1_Rain              0.290093      0.004221       -0.395359
# Weather_Condition1_Thunder_Storm     0.101956     -0.018770       -0.154926
# Weather_Condition1_Wintery_Mix       0.020094     -0.004969       -0.049680
# Sunrise_Sunset_Day                  -0.229900      0.012949        0.017914
# Sunrise_Sunset_Night                 0.229900     -0.012949       -0.017914
# Civil_Twilight_Day                  -0.201847      0.018042        0.011564
# Civil_Twilight_Night                 0.201847     -0.018042       -0.011564
# Nautical_Twilight_Day               -0.176512      0.020823        0.007473
# Nautical_Twilight_Night              0.176512     -0.020823       -0.007473
# Astronomical_Twilight_Day           -0.155777      0.021945        0.004793
# Astronomical_Twilight_Night          0.155777     -0.021945       -0.004793
# Road_Type_Highway                    0.031228      0.017691        0.000393
# Road_Type_Street                    -0.031228     -0.017691       -0.000393
#
#                                   Wind_Speed(mph)  Precipitation(in)  \
# Init_Severity                            0.058645           0.022178
# Distance(mi)                             0.003338          -0.001220
# Temperature(F)                           0.033429          -0.039488
# Humidity(%)                             -0.137554           0.143523
# Pressure(in)                             0.007541           0.001085
# Visibility(mi)                           0.031710          -0.257520
# Wind_Speed(mph)                          1.000000           0.026851
# Precipitation(in)                        0.026851           1.000000
# Amenity                                 -0.038339          -0.002347
# Bump                                    -0.000202          -0.000698
# Crossing                                 0.001035          -0.002458
# Give_Way                                 0.001355          -0.000746
# Junction                                 0.018714           0.005063
# No_Exit                                  0.004603          -0.000264
# Railway                                  0.005738          -0.002061
# Roundabout                               0.000134           0.000235
# Station                                 -0.041098          -0.001227
# Stop                                     0.004303          -0.002896
# Traffic_Calming                         -0.007651          -0.000994
# Traffic_Signal                          -0.010477          -0.011626
# Turning_Loop                                  NaN                NaN
# Side_L                                  -0.028833          -0.012330
# Side_R                                   0.028833           0.012330
# Weather_Condition1_Clear                -0.156007          -0.084700
# Weather_Condition1_Cloudy                0.129387          -0.096696
# Weather_Condition1_Fog_Haze             -0.047589          -0.006752
# Weather_Condition1_Rain                  0.048055           0.215642
# Weather_Condition1_Thunder_Storm         0.040352           0.335949
# Weather_Condition1_Wintery_Mix           0.023010           0.005095
# Sunrise_Sunset_Day                       0.132622          -0.007949
# Sunrise_Sunset_Night                    -0.132622           0.007949
# Civil_Twilight_Day                       0.117645          -0.008539
# Civil_Twilight_Night                    -0.117645           0.008539
# Nautical_Twilight_Day                    0.106062          -0.005808
# Nautical_Twilight_Night                 -0.106062           0.005808
# Astronomical_Twilight_Day                0.098581          -0.003983
# Astronomical_Twilight_Night             -0.098581           0.003983
# Road_Type_Highway                        0.043626           0.022730
# Road_Type_Street                        -0.043626          -0.022730
#
#                                    Amenity      Bump  Crossing  Give_Way  \
# Init_Severity                    -0.075669 -0.006837 -0.133186  0.019790
# Distance(mi)                     -0.022151 -0.001563 -0.050808 -0.010526
# Temperature(F)                    0.019778  0.000085  0.008360  0.010909
# Humidity(%)                      -0.020076  0.000108  0.002320  0.011538
# Pressure(in)                      0.006007  0.001122  0.050308  0.022481
# Visibility(mi)                    0.006491  0.001070 -0.002569 -0.006828
# Wind_Speed(mph)                  -0.038339 -0.000202  0.001035  0.001355
# Precipitation(in)                -0.002347 -0.000698 -0.002458 -0.000746
# Amenity                           1.000000 -0.001635  0.115094 -0.008797
# Bump                             -0.001635  1.000000  0.006274 -0.001129
# Crossing                          0.115094  0.006274  1.000000  0.116153
# Give_Way                         -0.008797 -0.001129  0.116153  1.000000
# Junction                         -0.027738 -0.003005 -0.064470 -0.014852
# No_Exit                          -0.000682 -0.000438  0.050234 -0.002305
# Railway                           0.026324 -0.001205  0.309698  0.005901
# Roundabout                        0.001879 -0.000100 -0.002493 -0.000747
# Station                           0.433621 -0.001471  0.080011 -0.010709
# Stop                              0.016375  0.027601  0.070574  0.007832
# Traffic_Calming                   0.035051  0.585455  0.034732 -0.001929
# Traffic_Signal                    0.088153 -0.007768  0.366178  0.081766
# Turning_Loop                           NaN       NaN       NaN       NaN
# Side_L                            0.061728  0.003118  0.059166 -0.025572
# Side_R                           -0.061728 -0.003118 -0.059166  0.025572
# Weather_Condition1_Clear          0.017711  0.001474 -0.021698 -0.013640
# Weather_Condition1_Cloudy        -0.013502 -0.001229  0.026251  0.016604
# Weather_Condition1_Fog_Haze       0.000379  0.002346  0.007576  0.005535
# Weather_Condition1_Rain          -0.006691 -0.002043 -0.013564 -0.008547
# Weather_Condition1_Thunder_Storm -0.001493  0.000846 -0.002993 -0.002952
# Weather_Condition1_Wintery_Mix   -0.002494 -0.000317 -0.002242 -0.002369
# Sunrise_Sunset_Day                0.013328  0.001988  0.015470  0.004111
# Sunrise_Sunset_Night             -0.013328 -0.001988 -0.015470 -0.004111
# Civil_Twilight_Day                0.010921  0.000738  0.014406  0.003196
# Civil_Twilight_Night             -0.010921 -0.000738 -0.014406 -0.003196
# Nautical_Twilight_Day             0.009299  0.000066  0.013269  0.003256
# Nautical_Twilight_Night          -0.009299 -0.000066 -0.013269 -0.003256
# Astronomical_Twilight_Day         0.007148 -0.000397  0.009880  0.003448
# Astronomical_Twilight_Night      -0.007148  0.000397 -0.009880 -0.003448
# Road_Type_Highway                -0.105084 -0.007781 -0.171993 -0.007843
# Road_Type_Street                  0.105084  0.007781  0.171993  0.007843
#
#                                   Junction   No_Exit   Railway  Roundabout  \
# Init_Severity                     0.143825 -0.015705 -0.048806   -0.004905
# Distance(mi)                      0.101699 -0.006215 -0.015917   -0.001362
# Temperature(F)                   -0.011858  0.000266 -0.002282   -0.003968
# Humidity(%)                       0.008025  0.002628  0.008689    0.003886
# Pressure(in)                      0.010979  0.008209  0.019688   -0.002474
# Visibility(mi)                    0.004066 -0.002502 -0.005064   -0.006079
# Wind_Speed(mph)                   0.018714  0.004603  0.005738    0.000134
# Precipitation(in)                 0.005063 -0.000264 -0.002061    0.000235
# Amenity                          -0.027738 -0.000682  0.026324    0.001879
# Bump                             -0.003005 -0.000438 -0.001205   -0.000100
# Crossing                         -0.064470  0.050234  0.309698   -0.002493
# Give_Way                         -0.014852 -0.002305  0.005901   -0.000747
# Junction                          1.000000 -0.008712 -0.018936    0.033233
# No_Exit                          -0.008712  1.000000  0.002875   -0.000290
# Railway                          -0.018936  0.002875  1.000000   -0.000797
# Roundabout                        0.033233 -0.000290 -0.000797    1.000000
# Station                          -0.028693 -0.004264  0.035994   -0.000973
# Stop                             -0.033815  0.023937  0.008187   -0.001228
# Traffic_Calming                  -0.005132 -0.000748 -0.002059   -0.000171
# Traffic_Signal                   -0.124058  0.003509  0.093663   -0.005138
# Turning_Loop                           NaN       NaN       NaN         NaN
# Side_L                           -0.119808  0.016659  0.028085    0.003430
# Side_R                            0.119808 -0.016659 -0.028085   -0.003430
# Weather_Condition1_Clear         -0.007339 -0.005660 -0.006415   -0.000437
# Weather_Condition1_Cloudy         0.004095  0.005053  0.007561   -0.000424
# Weather_Condition1_Fog_Haze      -0.005261  0.005576  0.006641    0.001926
# Weather_Condition1_Rain           0.004997 -0.001246 -0.005319   -0.000437
# Weather_Condition1_Thunder_Storm  0.008086 -0.001754 -0.002132    0.002479
# Weather_Condition1_Wintery_Mix    0.002167 -0.000918 -0.001270   -0.000209
# Sunrise_Sunset_Day               -0.021486 -0.001999  0.007151    0.000375
# Sunrise_Sunset_Night              0.021486  0.001999 -0.007151   -0.000375
# Civil_Twilight_Day               -0.022355 -0.002930  0.006610   -0.000518
# Civil_Twilight_Night              0.022355  0.002930 -0.006610    0.000518
# Nautical_Twilight_Day            -0.022549 -0.002839  0.005020   -0.001507
# Nautical_Twilight_Night           0.022549  0.002839 -0.005020    0.001507
# Astronomical_Twilight_Day        -0.021517 -0.003021  0.004404   -0.002458
# Astronomical_Twilight_Night       0.021517  0.003021 -0.004404    0.002458
# Road_Type_Highway                 0.236313 -0.026678 -0.065106   -0.006864
# Road_Type_Street                 -0.236313  0.026678  0.065106    0.006864
#
#                                    Station      Stop  Traffic_Calming  \
# Init_Severity                    -0.068260 -0.082532        -0.009955
# Distance(mi)                     -0.020821 -0.025841        -0.003426
# Temperature(F)                    0.024554  0.004605         0.002518
# Humidity(%)                      -0.019405  0.027153        -0.004240
# Pressure(in)                      0.005446  0.049544         0.000611
# Visibility(mi)                    0.006948 -0.019992         0.000202
# Wind_Speed(mph)                  -0.041098  0.004303        -0.007651
# Precipitation(in)                -0.001227 -0.002896        -0.000994
# Amenity                           0.433621  0.016375         0.035051
# Bump                             -0.001471  0.027601         0.585455
# Crossing                          0.080011  0.070574         0.034732
# Give_Way                         -0.010709  0.007832        -0.001929
# Junction                         -0.028693 -0.033815        -0.005132
# No_Exit                          -0.004264  0.023937        -0.000748
# Railway                           0.035994  0.008187        -0.002059
# Roundabout                       -0.000973 -0.001228        -0.000171
# Station                           1.000000 -0.005818         0.066091
# Stop                             -0.005818  1.000000         0.015094
# Traffic_Calming                   0.066091  0.015094         1.000000
# Traffic_Signal                    0.100353 -0.086049         0.009634
# Turning_Loop                           NaN       NaN              NaN
# Side_L                            0.049149  0.075548         0.009841
# Side_R                           -0.049149 -0.075548        -0.009841
# Weather_Condition1_Clear          0.017404 -0.006873         0.002414
# Weather_Condition1_Cloudy        -0.013500  0.008932        -0.002401
# Weather_Condition1_Fog_Haze      -0.002126  0.016866         0.001880
# Weather_Condition1_Rain          -0.004638 -0.010010        -0.000291
# Weather_Condition1_Thunder_Storm -0.001763 -0.007596        -0.001089
# Weather_Condition1_Wintery_Mix   -0.002049 -0.003067        -0.000541
# Sunrise_Sunset_Day                0.016446  0.017534         0.004166
# Sunrise_Sunset_Night             -0.016446 -0.017534        -0.004166
# Civil_Twilight_Day                0.013905  0.014011         0.003919
# Civil_Twilight_Night             -0.013905 -0.014011        -0.003919
# Nautical_Twilight_Day             0.010498  0.011155         0.002247
# Nautical_Twilight_Night          -0.010498 -0.011155        -0.002247
# Astronomical_Twilight_Day         0.008461  0.006723         0.003017
# Astronomical_Twilight_Night      -0.008461 -0.006723        -0.003017
# Road_Type_Highway                -0.097840 -0.115348        -0.015596
# Road_Type_Street                  0.097840  0.115348         0.015596
#
#                                   Traffic_Signal  Turning_Loop    Side_L  \
# Init_Severity                          -0.223582           NaN -0.240818
# Distance(mi)                           -0.100343           NaN -0.071691
# Temperature(F)                          0.034125           NaN  0.024649
# Humidity(%)                            -0.025450           NaN -0.014280
# Pressure(in)                           -0.012059           NaN -0.008039
# Visibility(mi)                          0.003554           NaN -0.001108
# Wind_Speed(mph)                        -0.010477           NaN -0.028833
# Precipitation(in)                      -0.011626           NaN -0.012330
# Amenity                                 0.088153           NaN  0.061728
# Bump                                   -0.007768           NaN  0.003118
# Crossing                                0.366178           NaN  0.059166
# Give_Way                                0.081766           NaN -0.025572
# Junction                               -0.124058           NaN -0.119808
# No_Exit                                 0.003509           NaN  0.016659
# Railway                                 0.093663           NaN  0.028085
# Roundabout                             -0.005138           NaN  0.003430
# Station                                 0.100353           NaN  0.049149
# Stop                                   -0.086049           NaN  0.075548
# Traffic_Calming                         0.009634           NaN  0.009841
# Traffic_Signal                          1.000000           NaN  0.073283
# Turning_Loop                                 NaN           NaN       NaN
# Side_L                                  0.073283           NaN  1.000000
# Side_R                                 -0.073283           NaN -1.000000
# Weather_Condition1_Clear               -0.010989           NaN  0.009278
# Weather_Condition1_Cloudy               0.022139           NaN  0.000625
# Weather_Condition1_Fog_Haze             0.002063           NaN  0.009710
# Weather_Condition1_Rain                -0.019112           NaN -0.018048
# Weather_Condition1_Thunder_Storm       -0.012506           NaN -0.014440
# Weather_Condition1_Wintery_Mix         -0.001419           NaN -0.003049
# Sunrise_Sunset_Day                      0.041022           NaN  0.030819
# Sunrise_Sunset_Night                   -0.041022           NaN -0.030819
# Civil_Twilight_Day                      0.039502           NaN  0.025369
# Civil_Twilight_Night                   -0.039502           NaN -0.025369
# Nautical_Twilight_Day                   0.037482           NaN  0.017604
# Nautical_Twilight_Night                -0.037482           NaN -0.017604
# Astronomical_Twilight_Day               0.033563           NaN  0.010533
# Astronomical_Twilight_Night            -0.033563           NaN -0.010533
# Road_Type_Highway                      -0.333470           NaN -0.354356
# Road_Type_Street                        0.333470           NaN  0.354356
#
#                                     Side_R  Weather_Condition1_Clear  \
# Init_Severity                     0.240818                 -0.010850
# Distance(mi)                      0.071691                  0.022926
# Temperature(F)                   -0.024649                 -0.014781
# Humidity(%)                       0.014280                 -0.345431
# Pressure(in)                      0.008039                 -0.068980
# Visibility(mi)                    0.001108                  0.254410
# Wind_Speed(mph)                   0.028833                 -0.156007
# Precipitation(in)                 0.012330                 -0.084700
# Amenity                          -0.061728                  0.017711
# Bump                             -0.003118                  0.001474
# Crossing                         -0.059166                 -0.021698
# Give_Way                          0.025572                 -0.013640
# Junction                          0.119808                 -0.007339
# No_Exit                          -0.016659                 -0.005660
# Railway                          -0.028085                 -0.006415
# Roundabout                       -0.003430                 -0.000437
# Station                          -0.049149                  0.017404
# Stop                             -0.075548                 -0.006873
# Traffic_Calming                  -0.009841                  0.002414
# Traffic_Signal                   -0.073283                 -0.010989
# Turning_Loop                           NaN                       NaN
# Side_L                           -1.000000                  0.009278
# Side_R                            1.000000                 -0.009278
# Weather_Condition1_Clear         -0.009278                  1.000000
# Weather_Condition1_Cloudy        -0.000625                 -0.827153
# Weather_Condition1_Fog_Haze      -0.009710                 -0.098414
# Weather_Condition1_Rain           0.018048                 -0.189865
# Weather_Condition1_Thunder_Storm  0.014440                 -0.085994
# Weather_Condition1_Wintery_Mix    0.003049                 -0.019289
# Sunrise_Sunset_Day               -0.030819                 -0.066290
# Sunrise_Sunset_Night              0.030819                  0.066290
# Civil_Twilight_Day               -0.025369                 -0.067563
# Civil_Twilight_Night              0.025369                  0.067563
# Nautical_Twilight_Day            -0.017604                 -0.071415
# Nautical_Twilight_Night           0.017604                  0.071415
# Astronomical_Twilight_Day        -0.010533                 -0.071889
# Astronomical_Twilight_Night       0.010533                  0.071889
# Road_Type_Highway                 0.354356                 -0.006020
# Road_Type_Street                 -0.354356                  0.006020
#
#                                   Weather_Condition1_Cloudy  \
# Init_Severity                                     -0.007491
# Distance(mi)                                      -0.022516
# Temperature(F)                                     0.106161
# Humidity(%)                                        0.136680
# Pressure(in)                                       0.068707
# Visibility(mi)                                     0.077943
# Wind_Speed(mph)                                    0.129387
# Precipitation(in)                                 -0.096696
# Amenity                                           -0.013502
# Bump                                              -0.001229
# Crossing                                           0.026251
# Give_Way                                           0.016604
# Junction                                           0.004095
# No_Exit                                            0.005053
# Railway                                            0.007561
# Roundabout                                        -0.000424
# Station                                           -0.013500
# Stop                                               0.008932
# Traffic_Calming                                   -0.002401
# Traffic_Signal                                     0.022139
# Turning_Loop                                            NaN
# Side_L                                             0.000625
# Side_R                                            -0.000625
# Weather_Condition1_Clear                          -0.827153
# Weather_Condition1_Cloudy                          1.000000
# Weather_Condition1_Fog_Haze                       -0.145283
# Weather_Condition1_Rain                           -0.280288
# Weather_Condition1_Thunder_Storm                  -0.126949
# Weather_Condition1_Wintery_Mix                    -0.028475
# Sunrise_Sunset_Day                                 0.074821
# Sunrise_Sunset_Night                              -0.074821
# Civil_Twilight_Day                                 0.073590
# Civil_Twilight_Night                              -0.073590
# Nautical_Twilight_Day                              0.074610
# Nautical_Twilight_Night                           -0.074610
# Astronomical_Twilight_Day                          0.072387
# Astronomical_Twilight_Night                       -0.072387
# Road_Type_Highway                                 -0.013206
# Road_Type_Street                                   0.013206
#
#                                   Weather_Condition1_Fog_Haze  \
# Init_Severity                                       -0.014166
# Distance(mi)                                        -0.001738
# Temperature(F)                                      -0.049393
# Humidity(%)                                          0.127700
# Pressure(in)                                         0.001235
# Visibility(mi)                                      -0.369556
# Wind_Speed(mph)                                     -0.047589
# Precipitation(in)                                   -0.006752
# Amenity                                              0.000379
# Bump                                                 0.002346
# Crossing                                             0.007576
# Give_Way                                             0.005535
# Junction                                            -0.005261
# No_Exit                                              0.005576
# Railway                                              0.006641
# Roundabout                                           0.001926
# Station                                             -0.002126
# Stop                                                 0.016866
# Traffic_Calming                                      0.001880
# Traffic_Signal                                       0.002063
# Turning_Loop                                              NaN
# Side_L                                               0.009710
# Side_R                                              -0.009710
# Weather_Condition1_Clear                            -0.098414
# Weather_Condition1_Cloudy                           -0.145283
# Weather_Condition1_Fog_Haze                          1.000000
# Weather_Condition1_Rain                             -0.033348
# Weather_Condition1_Thunder_Storm                    -0.015104
# Weather_Condition1_Wintery_Mix                      -0.003388
# Sunrise_Sunset_Day                                  -0.006745
# Sunrise_Sunset_Night                                 0.006745
# Civil_Twilight_Day                                  -0.004428
# Civil_Twilight_Night                                 0.004428
# Nautical_Twilight_Day                               -0.004398
# Nautical_Twilight_Night                              0.004398
# Astronomical_Twilight_Day                           -0.007598
# Astronomical_Twilight_Night                          0.007598
# Road_Type_Highway                                   -0.015665
# Road_Type_Street                                     0.015665
#
#                                   Weather_Condition1_Rain  \
# Init_Severity                                    0.031327
# Distance(mi)                                     0.001015
# Temperature(F)                                  -0.161454
# Humidity(%)                                      0.290093
# Pressure(in)                                     0.004221
# Visibility(mi)                                  -0.395359
# Wind_Speed(mph)                                  0.048055
# Precipitation(in)                                0.215642
# Amenity                                         -0.006691
# Bump                                            -0.002043
# Crossing                                        -0.013564
# Give_Way                                        -0.008547
# Junction                                         0.004997
# No_Exit                                         -0.001246
# Railway                                         -0.005319
# Roundabout                                      -0.000437
# Station                                         -0.004638
# Stop                                            -0.010010
# Traffic_Calming                                 -0.000291
# Traffic_Signal                                  -0.019112
# Turning_Loop                                          NaN
# Side_L                                          -0.018048
# Side_R                                           0.018048
# Weather_Condition1_Clear                        -0.189865
# Weather_Condition1_Cloudy                       -0.280288
# Weather_Condition1_Fog_Haze                     -0.033348
# Weather_Condition1_Rain                          1.000000
# Weather_Condition1_Thunder_Storm                -0.029140
# Weather_Condition1_Wintery_Mix                  -0.006536
# Sunrise_Sunset_Day                              -0.017785
# Sunrise_Sunset_Night                             0.017785
# Civil_Twilight_Day                              -0.013994
# Civil_Twilight_Night                             0.013994
# Nautical_Twilight_Day                           -0.010043
# Nautical_Twilight_Night                          0.010043
# Astronomical_Twilight_Day                       -0.005019
# Astronomical_Twilight_Night                      0.005019
# Road_Type_Highway                                0.036142
# Road_Type_Street                                -0.036142
#
#                                   Weather_Condition1_Thunder_Storm  \
# Init_Severity                                             0.029099
# Distance(mi)                                             -0.002714
# Temperature(F)                                            0.007166
# Humidity(%)                                               0.101956
# Pressure(in)                                             -0.018770
# Visibility(mi)                                           -0.154926
# Wind_Speed(mph)                                           0.040352
# Precipitation(in)                                         0.335949
# Amenity                                                  -0.001493
# Bump                                                      0.000846
# Crossing                                                 -0.002993
# Give_Way                                                 -0.002952
# Junction                                                  0.008086
# No_Exit                                                  -0.001754
# Railway                                                  -0.002132
# Roundabout                                                0.002479
# Station                                                  -0.001763
# Stop                                                     -0.007596
# Traffic_Calming                                          -0.001089
# Traffic_Signal                                           -0.012506
# Turning_Loop                                                   NaN
# Side_L                                                   -0.014440
# Side_R                                                    0.014440
# Weather_Condition1_Clear                                 -0.085994
# Weather_Condition1_Cloudy                                -0.126949
# Weather_Condition1_Fog_Haze                              -0.015104
# Weather_Condition1_Rain                                  -0.029140
# Weather_Condition1_Thunder_Storm                          1.000000
# Weather_Condition1_Wintery_Mix                           -0.002960
# Sunrise_Sunset_Day                                       -0.002411
# Sunrise_Sunset_Night                                      0.002411
# Civil_Twilight_Day                                       -0.002019
# Civil_Twilight_Night                                      0.002019
# Nautical_Twilight_Day                                     0.001380
# Nautical_Twilight_Night                                  -0.001380
# Astronomical_Twilight_Day                                 0.006040
# Astronomical_Twilight_Night                              -0.006040
# Road_Type_Highway                                         0.024399
# Road_Type_Street                                         -0.024399
#
#                                   Weather_Condition1_Wintery_Mix  \
# Init_Severity                                          -0.000092
# Distance(mi)                                            0.019200
# Temperature(F)                                         -0.065135
# Humidity(%)                                             0.020094
# Pressure(in)                                           -0.004969
# Visibility(mi)                                         -0.049680
# Wind_Speed(mph)                                         0.023010
# Precipitation(in)                                       0.005095
# Amenity                                                -0.002494
# Bump                                                   -0.000317
# Crossing                                               -0.002242
# Give_Way                                               -0.002369
# Junction                                                0.002167
# No_Exit                                                -0.000918
# Railway                                                -0.001270
# Roundabout                                             -0.000209
# Station                                                -0.002049
# Stop                                                   -0.003067
# Traffic_Calming                                        -0.000541
# Traffic_Signal                                         -0.001419
# Turning_Loop                                                 NaN
# Side_L                                                 -0.003049
# Side_R                                                  0.003049
# Weather_Condition1_Clear                               -0.019289
# Weather_Condition1_Cloudy                              -0.028475
# Weather_Condition1_Fog_Haze                            -0.003388
# Weather_Condition1_Rain                                -0.006536
# Weather_Condition1_Thunder_Storm                       -0.002960
# Weather_Condition1_Wintery_Mix                          1.000000
# Sunrise_Sunset_Day                                     -0.001533
# Sunrise_Sunset_Night                                    0.001533
# Civil_Twilight_Day                                     -0.002468
# Civil_Twilight_Night                                    0.002468
# Nautical_Twilight_Day                                  -0.002091
# Nautical_Twilight_Night                                 0.002091
# Astronomical_Twilight_Day                              -0.001272
# Astronomical_Twilight_Night                             0.001272
# Road_Type_Highway                                       0.004003
# Road_Type_Street                                       -0.004003
#
#                                   Sunrise_Sunset_Day  Sunrise_Sunset_Night  \
# Init_Severity                              -0.022088              0.022088
# Distance(mi)                               -0.056930              0.056930
# Temperature(F)                              0.297967             -0.297967
# Humidity(%)                                -0.229900              0.229900
# Pressure(in)                                0.012949             -0.012949
# Visibility(mi)                              0.017914             -0.017914
# Wind_Speed(mph)                             0.132622             -0.132622
# Precipitation(in)                          -0.007949              0.007949
# Amenity                                     0.013328             -0.013328
# Bump                                        0.001988             -0.001988
# Crossing                                    0.015470             -0.015470
# Give_Way                                    0.004111             -0.004111
# Junction                                   -0.021486              0.021486
# No_Exit                                    -0.001999              0.001999
# Railway                                     0.007151             -0.007151
# Roundabout                                  0.000375             -0.000375
# Station                                     0.016446             -0.016446
# Stop                                        0.017534             -0.017534
# Traffic_Calming                             0.004166             -0.004166
# Traffic_Signal                              0.041022             -0.041022
# Turning_Loop                                     NaN                   NaN
# Side_L                                      0.030819             -0.030819
# Side_R                                     -0.030819              0.030819
# Weather_Condition1_Clear                   -0.066290              0.066290
# Weather_Condition1_Cloudy                   0.074821             -0.074821
# Weather_Condition1_Fog_Haze                -0.006745              0.006745
# Weather_Condition1_Rain                    -0.017785              0.017785
# Weather_Condition1_Thunder_Storm           -0.002411              0.002411
# Weather_Condition1_Wintery_Mix             -0.001533              0.001533
# Sunrise_Sunset_Day                          1.000000             -1.000000
# Sunrise_Sunset_Night                       -1.000000              1.000000
# Civil_Twilight_Day                          0.878992             -0.878992
# Civil_Twilight_Night                       -0.878992              0.878992
# Nautical_Twilight_Day                       0.763250             -0.763250
# Nautical_Twilight_Night                    -0.763250              0.763250
# Astronomical_Twilight_Day                   0.668855             -0.668855
# Astronomical_Twilight_Night                -0.668855              0.668855
# Road_Type_Highway                          -0.058067              0.058067
# Road_Type_Street                            0.058067             -0.058067
#
#                                   Civil_Twilight_Day  Civil_Twilight_Night  \
# Init_Severity                              -0.014766              0.014766
# Distance(mi)                               -0.062309              0.062309
# Temperature(F)                              0.273854             -0.273854
# Humidity(%)                                -0.201847              0.201847
# Pressure(in)                                0.018042             -0.018042
# Visibility(mi)                              0.011564             -0.011564
# Wind_Speed(mph)                             0.117645             -0.117645
# Precipitation(in)                          -0.008539              0.008539
# Amenity                                     0.010921             -0.010921
# Bump                                        0.000738             -0.000738
# Crossing                                    0.014406             -0.014406
# Give_Way                                    0.003196             -0.003196
# Junction                                   -0.022355              0.022355
# No_Exit                                    -0.002930              0.002930
# Railway                                     0.006610             -0.006610
# Roundabout                                 -0.000518              0.000518
# Station                                     0.013905             -0.013905
# Stop                                        0.014011             -0.014011
# Traffic_Calming                             0.003919             -0.003919
# Traffic_Signal                              0.039502             -0.039502
# Turning_Loop                                     NaN                   NaN
# Side_L                                      0.025369             -0.025369
# Side_R                                     -0.025369              0.025369
# Weather_Condition1_Clear                   -0.067563              0.067563
# Weather_Condition1_Cloudy                   0.073590             -0.073590
# Weather_Condition1_Fog_Haze                -0.004428              0.004428
# Weather_Condition1_Rain                    -0.013994              0.013994
# Weather_Condition1_Thunder_Storm           -0.002019              0.002019
# Weather_Condition1_Wintery_Mix             -0.002468              0.002468
# Sunrise_Sunset_Day                          0.878992             -0.878992
# Sunrise_Sunset_Night                       -0.878992              0.878992
# Civil_Twilight_Day                          1.000000             -1.000000
# Civil_Twilight_Night                       -1.000000              1.000000
# Nautical_Twilight_Day                       0.868324             -0.868324
# Nautical_Twilight_Night                    -0.868324              0.868324
# Astronomical_Twilight_Day                   0.760934             -0.760934
# Astronomical_Twilight_Night                -0.760934              0.760934
# Road_Type_Highway                          -0.050498              0.050498
# Road_Type_Street                            0.050498             -0.050498
#
#                                   Nautical_Twilight_Day  \
# Init_Severity                                 -0.003523
# Distance(mi)                                  -0.067793
# Temperature(F)                                 0.249733
# Humidity(%)                                   -0.176512
# Pressure(in)                                   0.020823
# Visibility(mi)                                 0.007473
# Wind_Speed(mph)                                0.106062
# Precipitation(in)                             -0.005808
# Amenity                                        0.009299
# Bump                                           0.000066
# Crossing                                       0.013269
# Give_Way                                       0.003256
# Junction                                      -0.022549
# No_Exit                                       -0.002839
# Railway                                        0.005020
# Roundabout                                    -0.001507
# Station                                        0.010498
# Stop                                           0.011155
# Traffic_Calming                                0.002247
# Traffic_Signal                                 0.037482
# Turning_Loop                                        NaN
# Side_L                                         0.017604
# Side_R                                        -0.017604
# Weather_Condition1_Clear                      -0.071415
# Weather_Condition1_Cloudy                      0.074610
# Weather_Condition1_Fog_Haze                   -0.004398
# Weather_Condition1_Rain                       -0.010043
# Weather_Condition1_Thunder_Storm               0.001380
# Weather_Condition1_Wintery_Mix                -0.002091
# Sunrise_Sunset_Day                             0.763250
# Sunrise_Sunset_Night                          -0.763250
# Civil_Twilight_Day                             0.868324
# Civil_Twilight_Night                          -0.868324
# Nautical_Twilight_Day                          1.000000
# Nautical_Twilight_Night                       -1.000000
# Astronomical_Twilight_Day                      0.876325
# Astronomical_Twilight_Night                   -0.876325
# Road_Type_Highway                             -0.039934
# Road_Type_Street                               0.039934
#
#                                   Nautical_Twilight_Night  \
# Init_Severity                                    0.003523
# Distance(mi)                                     0.067793
# Temperature(F)                                  -0.249733
# Humidity(%)                                      0.176512
# Pressure(in)                                    -0.020823
# Visibility(mi)                                  -0.007473
# Wind_Speed(mph)                                 -0.106062
# Precipitation(in)                                0.005808
# Amenity                                         -0.009299
# Bump                                            -0.000066
# Crossing                                        -0.013269
# Give_Way                                        -0.003256
# Junction                                         0.022549
# No_Exit                                          0.002839
# Railway                                         -0.005020
# Roundabout                                       0.001507
# Station                                         -0.010498
# Stop                                            -0.011155
# Traffic_Calming                                 -0.002247
# Traffic_Signal                                  -0.037482
# Turning_Loop                                          NaN
# Side_L                                          -0.017604
# Side_R                                           0.017604
# Weather_Condition1_Clear                         0.071415
# Weather_Condition1_Cloudy                       -0.074610
# Weather_Condition1_Fog_Haze                      0.004398
# Weather_Condition1_Rain                          0.010043
# Weather_Condition1_Thunder_Storm                -0.001380
# Weather_Condition1_Wintery_Mix                   0.002091
# Sunrise_Sunset_Day                              -0.763250
# Sunrise_Sunset_Night                             0.763250
# Civil_Twilight_Day                              -0.868324
# Civil_Twilight_Night                             0.868324
# Nautical_Twilight_Day                           -1.000000
# Nautical_Twilight_Night                          1.000000
# Astronomical_Twilight_Day                       -0.876325
# Astronomical_Twilight_Night                      0.876325
# Road_Type_Highway                                0.039934
# Road_Type_Street                                -0.039934
#
#                                   Astronomical_Twilight_Day  \
# Init_Severity                                      0.009981
# Distance(mi)                                      -0.072134
# Temperature(F)                                     0.231905
# Humidity(%)                                       -0.155777
# Pressure(in)                                       0.021945
# Visibility(mi)                                     0.004793
# Wind_Speed(mph)                                    0.098581
# Precipitation(in)                                 -0.003983
# Amenity                                            0.007148
# Bump                                              -0.000397
# Crossing                                           0.009880
# Give_Way                                           0.003448
# Junction                                          -0.021517
# No_Exit                                           -0.003021
# Railway                                            0.004404
# Roundabout                                        -0.002458
# Station                                            0.008461
# Stop                                               0.006723
# Traffic_Calming                                    0.003017
# Traffic_Signal                                     0.033563
# Turning_Loop                                            NaN
# Side_L                                             0.010533
# Side_R                                            -0.010533
# Weather_Condition1_Clear                          -0.071889
# Weather_Condition1_Cloudy                          0.072387
# Weather_Condition1_Fog_Haze                       -0.007598
# Weather_Condition1_Rain                           -0.005019
# Weather_Condition1_Thunder_Storm                   0.006040
# Weather_Condition1_Wintery_Mix                    -0.001272
# Sunrise_Sunset_Day                                 0.668855
# Sunrise_Sunset_Night                              -0.668855
# Civil_Twilight_Day                                 0.760934
# Civil_Twilight_Night                              -0.760934
# Nautical_Twilight_Day                              0.876325
# Nautical_Twilight_Night                           -0.876325
# Astronomical_Twilight_Day                          1.000000
# Astronomical_Twilight_Night                       -1.000000
# Road_Type_Highway                                 -0.028185
# Road_Type_Street                                   0.028185
#
#                                   Astronomical_Twilight_Night  \
# Init_Severity                                       -0.009981
# Distance(mi)                                         0.072134
# Temperature(F)                                      -0.231905
# Humidity(%)                                          0.155777
# Pressure(in)                                        -0.021945
# Visibility(mi)                                      -0.004793
# Wind_Speed(mph)                                     -0.098581
# Precipitation(in)                                    0.003983
# Amenity                                             -0.007148
# Bump                                                 0.000397
# Crossing                                            -0.009880
# Give_Way                                            -0.003448
# Junction                                             0.021517
# No_Exit                                              0.003021
# Railway                                             -0.004404
# Roundabout                                           0.002458
# Station                                             -0.008461
# Stop                                                -0.006723
# Traffic_Calming                                     -0.003017
# Traffic_Signal                                      -0.033563
# Turning_Loop                                              NaN
# Side_L                                              -0.010533
# Side_R                                               0.010533
# Weather_Condition1_Clear                             0.071889
# Weather_Condition1_Cloudy                           -0.072387
# Weather_Condition1_Fog_Haze                          0.007598
# Weather_Condition1_Rain                              0.005019
# Weather_Condition1_Thunder_Storm                    -0.006040
# Weather_Condition1_Wintery_Mix                       0.001272
# Sunrise_Sunset_Day                                  -0.668855
# Sunrise_Sunset_Night                                 0.668855
# Civil_Twilight_Day                                  -0.760934
# Civil_Twilight_Night                                 0.760934
# Nautical_Twilight_Day                               -0.876325
# Nautical_Twilight_Night                              0.876325
# Astronomical_Twilight_Day                           -1.000000
# Astronomical_Twilight_Night                          1.000000
# Road_Type_Highway                                    0.028185
# Road_Type_Street                                    -0.028185
#
#                                   Road_Type_Highway  Road_Type_Street
# Init_Severity                              0.440856         -0.440856
# Distance(mi)                               0.172745         -0.172745
# Temperature(F)                            -0.045925          0.045925
# Humidity(%)                                0.031228         -0.031228
# Pressure(in)                               0.017691         -0.017691
# Visibility(mi)                             0.000393         -0.000393
# Wind_Speed(mph)                            0.043626         -0.043626
# Precipitation(in)                          0.022730         -0.022730
# Amenity                                   -0.105084          0.105084
# Bump                                      -0.007781          0.007781
# Crossing                                  -0.171993          0.171993
# Give_Way                                  -0.007843          0.007843
# Junction                                   0.236313         -0.236313
# No_Exit                                   -0.026678          0.026678
# Railway                                   -0.065106          0.065106
# Roundabout                                -0.006864          0.006864
# Station                                   -0.097840          0.097840
# Stop                                      -0.115348          0.115348
# Traffic_Calming                           -0.015596          0.015596
# Traffic_Signal                            -0.333470          0.333470
# Turning_Loop                                    NaN               NaN
# Side_L                                    -0.354356          0.354356
# Side_R                                     0.354356         -0.354356
# Weather_Condition1_Clear                  -0.006020          0.006020
# Weather_Condition1_Cloudy                 -0.013206          0.013206
# Weather_Condition1_Fog_Haze               -0.015665          0.015665
# Weather_Condition1_Rain                    0.036142         -0.036142
# Weather_Condition1_Thunder_Storm           0.024399         -0.024399
# Weather_Condition1_Wintery_Mix             0.004003         -0.004003
# Sunrise_Sunset_Day                        -0.058067          0.058067
# Sunrise_Sunset_Night                       0.058067         -0.058067
# Civil_Twilight_Day                        -0.050498          0.050498
# Civil_Twilight_Night                       0.050498         -0.050498
# Nautical_Twilight_Day                     -0.039934          0.039934
# Nautical_Twilight_Night                    0.039934         -0.039934
# Astronomical_Twilight_Day                 -0.028185          0.028185
# Astronomical_Twilight_Night                0.028185         -0.028185
# Road_Type_Highway                          1.000000         -1.000000
# Road_Type_Street                          -1.000000          1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_sub_other.corr())
plt.show()

# %%
df_sub_linear.groupby("Init_Severity").size()
# Out:
# Init_Severity
# 0.0    233079
# 1.0     84896
# dtype: int64

# %% [markdown]
# # Linear Models for Initial Severity

# %%
# get pandas columns for prediction
target = df_sub_linear["Init_Severity"]
features = df_sub_linear.drop(["Init_Severity"], axis=1)

# convert to lists/arrays (MUST HAPPEN)
X = np.array(features)
y = np.array(target)

# train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=18)

# %%
reg = LogisticRegression()
reg.fit(X_train, y_train)

#get predictions
in_sample_preds = reg.predict(X_train)
out_sample_preds = reg.predict(X_test)

# get evaluation report
print("Logistic Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = reg.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# C:\Users\Ryan Permenter\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Classifier:
# Classification Report - In Sample
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.84      0.84    186440
#          1.0       0.55      0.55      0.55     67940
#
#     accuracy                           0.76    254380
#    macro avg       0.69      0.70      0.69    254380
# weighted avg       0.76      0.76      0.76    254380
#
#
# Confusion Matrix - In Sample
# [[155965  30475]
#  [ 30322  37618]]
#
#
# Classification Report - Out Sample
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.84      0.84     46639
#          1.0       0.55      0.55      0.55     16956
#
#     accuracy                           0.76     63595
#    macro avg       0.70      0.69      0.69     63595
# weighted avg       0.76      0.76      0.76     63595
#
#
# Confusion Matrix - Out Sample
# [[39123  7516]
#  [ 7635  9321]]

# %% [markdown]
# # Other Models for Initial Severity

# %%
# get pandas columns for prediction
target = df_sub_other["Init_Severity"]
features = df_sub_other.drop(["Init_Severity"], axis=1)

# convert to lists/arrays (MUST HAPPEN)
X = np.array(features)
y = np.array(target)

# train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=18)

# %%
# train the model
dt = DecisionTreeClassifier(random_state=18)
dt.fit(X_train, y_train)

#get predictions
in_sample_preds = dt.predict(X_train)
out_sample_preds = dt.predict(X_test)

# get evaluation report
print("Decision Tree Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = dt.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# Decision Tree Classifier:
# Classification Report - In Sample
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99    186440
#          1.0       1.00      0.96      0.98     67940
#
#     accuracy                           0.99    254380
#    macro avg       0.99      0.98      0.99    254380
# weighted avg       0.99      0.99      0.99    254380
#
#
# Confusion Matrix - In Sample
# [[186207    233]
#  [  2545  65395]]
#
#
# Classification Report - Out Sample
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.82      0.82     46639
#          1.0       0.50      0.50      0.50     16956
#
#     accuracy                           0.74     63595
#    macro avg       0.66      0.66      0.66     63595
# weighted avg       0.74      0.74      0.74     63595
#
#
# Confusion Matrix - Out Sample
# [[38227  8412]
#  [ 8424  8532]]

# %%
# train the model
rf = RandomForestClassifier(random_state=18, n_estimators=100)
rf.fit(X_train, y_train)

#get predictions
in_sample_preds = rf.predict(X_train)
out_sample_preds = rf.predict(X_test)

# get evaluation report
print("Random Forest Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = rf.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds, pos_label=2)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

pd.DataFrame(list(zip(features.columns, rf.feature_importances_))).sort_values(by=1, ascending=False).head(10)
# Out:
# Random Forest Classifier:
# Classification Report - In Sample
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99    186440
#          1.0       0.98      0.98      0.98     67940
#
#     accuracy                           0.99    254380
#    macro avg       0.99      0.99      0.99    254380
# weighted avg       0.99      0.99      0.99    254380
#
#
# Confusion Matrix - In Sample
# [[185249   1191]
#  [  1593  66347]]
#
#
# Classification Report - Out Sample
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.88      0.86     46639
#          1.0       0.62      0.53      0.57     16956
#
#     accuracy                           0.79     63595
#    macro avg       0.73      0.70      0.71     63595
# weighted avg       0.78      0.79      0.78     63595
#
#
# Confusion Matrix - Out Sample
# [[41061  5578]
#  [ 7985  8971]]
# C:\Users\Ryan Permenter\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py:811: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn("No positive samples in y_true, "
#                     0         1
# 3        Pressure(in)  0.187284
# 1      Temperature(F)  0.166351
# 2         Humidity(%)  0.156395
# 5     Wind_Speed(mph)  0.105118
# 37   Road_Type_Street  0.090786
# 0        Distance(mi)  0.069396
# 36  Road_Type_Highway  0.066221
# 4      Visibility(mi)  0.032274
# 18     Traffic_Signal  0.024467
# 21             Side_R  0.019821

# %%
# train the model
ada = AdaBoostClassifier(random_state=18)
ada.fit(X_train, y_train)

#get predictions
in_sample_preds = ada.predict(X_train)
out_sample_preds = ada.predict(X_test)

# get evaluation report
print("Ada Boost Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = ada.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# Ada Boost Classifier:
# Classification Report - In Sample
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.86      0.85    186440
#          1.0       0.58      0.54      0.56     67940
#
#     accuracy                           0.77    254380
#    macro avg       0.71      0.70      0.71    254380
# weighted avg       0.77      0.77      0.77    254380
#
#
# Confusion Matrix - In Sample
# [[160002  26438]
#  [ 30938  37002]]
#
#
# Classification Report - Out Sample
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.86      0.85     46639
#          1.0       0.59      0.55      0.57     16956
#
#     accuracy                           0.78     63595
#    macro avg       0.72      0.71      0.71     63595
# weighted avg       0.77      0.78      0.78     63595
#
#
# Confusion Matrix - Out Sample
# [[40283  6356]
#  [ 7667  9289]]

# %%
# train the model
gb = GradientBoostingClassifier(random_state=18)
gb.fit(X_train, y_train)

#get predictions
in_sample_preds = gb.predict(X_train)
out_sample_preds = gb.predict(X_test)

# get evaluation report
print("GradientBoosting Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = gb.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
# train the model
xgb = XGBClassifier(random_state=18)
xgb.fit(X_train, y_train)

#get predictions
in_sample_preds = xgb.predict(X_train)
out_sample_preds = xgb.predict(X_test)

# get evaluation report
print("XG Boost Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = xgb.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
# save the model to disk
filename = 'initial_model.sav'
pickle.dump(xgb, open(filename, 'wb'))

# %% [markdown]
# # Mild Severity Models

# %%
df_mild_linear["Severity"].replace((2, 1), (1, 0), inplace=True)

# get pandas columns for prediction
target = df_mild_linear["Severity"]
features = df_mild_linear.drop(["Severity"], axis=1)

# convert to lists/arrays (MUST HAPPEN)
X = np.array(features)
y = np.array(target)

# train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=18)

# %%
reg = LogisticRegression()
reg.fit(X_train, y_train)

#get predictions
in_sample_preds = reg.predict(X_train)
out_sample_preds = reg.predict(X_test)

# get evaluation report
print("Logistic Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = reg.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
df_mild_other["Severity"].replace((2, 1), (1, 0), inplace=True)

# get pandas columns for prediction
target = df_mild_other["Severity"]
features = df_mild_other.drop(["Severity"], axis=1)

# convert to lists/arrays (MUST HAPPEN)
X = np.array(features)
y = np.array(target)

# train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=18)

# %%
# train the model
dt = DecisionTreeClassifier(random_state=18)
dt.fit(X_train, y_train)

#get predictions
in_sample_preds = dt.predict(X_train)
out_sample_preds = dt.predict(X_test)

# get evaluation report
print("Decision Tree Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = dt.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
# train the model
rf = RandomForestClassifier(random_state=18, n_estimators=100)
rf.fit(X_train, y_train)

#get predictions
in_sample_preds = rf.predict(X_train)
out_sample_preds = rf.predict(X_test)

# get evaluation report
print("Random Forest Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = rf.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds, pos_label=2)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

pd.DataFrame(list(zip(features.columns, rf.feature_importances_))).sort_values(by=1, ascending=False).head(10)

# %%
# save the model to disk
filename = 'mild_model.sav'
pickle.dump(rf, open(filename, 'wb'))

# %%
# train the model
ada = AdaBoostClassifier(random_state=18)
ada.fit(X_train, y_train)

#get predictions
in_sample_preds = ada.predict(X_train)
out_sample_preds = ada.predict(X_test)

# get evaluation report
print("Ada Boost Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = ada.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
# train the model
gb = GradientBoostingClassifier(random_state=18)
gb.fit(X_train, y_train)

#get predictions
in_sample_preds = gb.predict(X_train)
out_sample_preds = gb.predict(X_test)

# get evaluation report
print("GradientBoosting Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = gb.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
# train the model
xgb = XGBClassifier(random_state=18)
xgb.fit(X_train, y_train)

#get predictions
in_sample_preds = xgb.predict(X_train)
out_sample_preds = xgb.predict(X_test)

# get evaluation report
print("XG Boost Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = xgb.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# # Severe Severity Models

# %%
df_severe_linear["Severity"].replace((4, 3), (1, 0), inplace=True)

# get pandas columns for prediction
target = df_severe_linear["Severity"]
features = df_severe_linear.drop(["Severity"], axis=1)

# convert to lists/arrays (MUST HAPPEN)
X = np.array(features)
y = np.array(target)

# train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=18)

# %%
reg = LogisticRegression()
reg.fit(X_train, y_train)

#get predictions
in_sample_preds = reg.predict(X_train)
out_sample_preds = reg.predict(X_test)

# get evaluation report
print("Logistic Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = reg.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
df_severe_other["Severity"].replace((4, 3), (1, 0), inplace=True)

# get pandas columns for prediction
target = df_severe_other["Severity"]
features = df_severe_other.drop(["Severity"], axis=1)

# convert to lists/arrays (MUST HAPPEN)
X = np.array(features)
y = np.array(target)

# train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=18)

# %%
# train the model
dt = DecisionTreeClassifier(random_state=18)
dt.fit(X_train, y_train)

#get predictions
in_sample_preds = dt.predict(X_train)
out_sample_preds = dt.predict(X_test)

# get evaluation report
print("Decision Tree Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = dt.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
# train the model
rf = RandomForestClassifier(random_state=18, n_estimators=100)
rf.fit(X_train, y_train)

#get predictions
in_sample_preds = rf.predict(X_train)
out_sample_preds = rf.predict(X_test)

# get evaluation report
print("Random Forest Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = rf.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds, pos_label=2)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

pd.DataFrame(list(zip(features.columns, rf.feature_importances_))).sort_values(by=1, ascending=False).head(10)

# %%
# save the model to disk
filename = 'severe_model.sav'
pickle.dump(rf, open(filename, 'wb'))

# %%
# train the model
ada = AdaBoostClassifier(random_state=18)
ada.fit(X_train, y_train)

#get predictions
in_sample_preds = ada.predict(X_train)
out_sample_preds = ada.predict(X_test)

# get evaluation report
print("Ada Boost Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = ada.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
# train the model
gb = GradientBoostingClassifier(random_state=18)
gb.fit(X_train, y_train)

#get predictions
in_sample_preds = gb.predict(X_train)
out_sample_preds = gb.predict(X_test)

# get evaluation report
print("GradientBoosting Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = gb.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
# train the model
xgb = XGBClassifier(random_state=18)
xgb.fit(X_train, y_train)

#get predictions
in_sample_preds = xgb.predict(X_train)
out_sample_preds = xgb.predict(X_test)

# get evaluation report
print("XG Boost Classifier:")
print("Classification Report - In Sample")
print(classification_report(y_train, in_sample_preds))
print()
print("Confusion Matrix - In Sample")
print(confusion_matrix(y_train, in_sample_preds))
print()
print()
print("Classification Report - Out Sample")
print(classification_report(y_test, out_sample_preds))
print()
print("Confusion Matrix - Out Sample")
print(confusion_matrix(y_test, out_sample_preds))

# get probabilities for the ROC curve
preds = xgb.predict_proba(X_test)[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# method I: plt
plt.figure(figsize=(10,6))
plt.title('ROC Curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
