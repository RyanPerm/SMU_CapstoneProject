# %%
import pandas as pd

# %%
df = pd.read_csv("TexasAccidents.csv")
df.head()
# Out:
#          ID    Source    TMC  Severity           Start_Time  \
# 0  A-261009  MapQuest  201.0         2  2016-11-30 16:03:54
# 1  A-261010  MapQuest  201.0         2  2016-11-30 16:32:18
# 2  A-261011  MapQuest  201.0         2  2016-11-30 16:31:45
# 3  A-261012  MapQuest  201.0         2  2016-11-30 16:06:49
# 4  A-261013  MapQuest  201.0         3  2016-11-30 16:35:01
#
#               End_Time  Start_Lat  Start_Lng  End_Lat  End_Lng  ...  \
# 0  2016-11-30 17:20:00  30.336502 -97.755646      NaN      NaN  ...
# 1  2016-11-30 17:47:02  30.328165 -97.694305      NaN      NaN  ...
# 2  2016-11-30 17:46:34  30.326077 -97.692307      NaN      NaN  ...
# 3  2016-11-30 17:27:00  32.856014 -97.513084      NaN      NaN  ...
# 4  2016-11-30 17:49:39  32.797668 -97.212090      NaN      NaN  ...
#
#    Roundabout Station   Stop Traffic_Calming Traffic_Signal Turning_Loop  \
# 0       False   False  False           False          False        False
# ...

# %%
df2 = df[df.County == "Dallas"]
df2.head()
# Out:
#          ID    Source    TMC  Severity           Start_Time  \
# 5  A-261014  MapQuest  201.0         2  2016-11-30 16:10:04
# 6  A-261015  MapQuest  201.0         3  2016-11-30 16:05:32
# 7  A-261016  MapQuest  201.0         2  2016-11-30 16:10:46
# 8  A-261017  MapQuest  201.0         2  2016-11-30 15:45:59
# 9  A-261018  MapQuest  201.0         3  2016-11-30 16:06:04
#
#               End_Time  Start_Lat  Start_Lng  End_Lat  End_Lng  ...  \
# 5  2016-11-30 17:25:00  32.662193 -96.943153      NaN      NaN  ...
# 6  2016-11-30 17:24:00  32.778790 -96.782021      NaN      NaN  ...
# 7  2016-11-30 17:27:00  32.724277 -96.762245      NaN      NaN  ...
# 8  2016-11-30 17:18:00  32.708355 -96.700043      NaN      NaN  ...
# 9  2016-11-30 17:20:42  32.864021 -96.661140      NaN      NaN  ...
#
#    Roundabout Station   Stop Traffic_Calming Traffic_Signal Turning_Loop  \
# 5       False   False  False           False          False        False
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90436 entries, 5 to 376437
# Data columns (total 49 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     90436 non-null  object
#  1   Source                 90436 non-null  object
#  2   TMC                    66866 non-null  float64
#  3   Severity               90436 non-null  int64
#  4   Start_Time             90436 non-null  object
#  5   End_Time               90436 non-null  object
#  6   Start_Lat              90436 non-null  float64
#  7   Start_Lng              90436 non-null  float64
#  8   End_Lat                23570 non-null  float64
#  9   End_Lng                23570 non-null  float64
#  10  Distance(mi)           90436 non-null  float64
#  11  Description            90436 non-null  object
#  12  Number                 23271 non-null  float64
#  13  Street                 90436 non-null  object
# ...

# %%
df2.to_csv (r'C:\Users\Ryan Permenter\Desktop\SMU\SMU_CapstoneProject\SMU_CapstoneProject\Data\DallasAccidents.csv', index = False, header=True)
